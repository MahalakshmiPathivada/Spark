-- %% [markdown]
-- ## 25 JOIN SCENARIO BASED INTERVIEW QUESTIONS

-- %% [markdown]
-- Example Data
-- Customer Table
--
-- - customer_id | customer_name | city
-- - 1 | Krishna | Hyderabad
-- - 2 | Sudheer | Bangalore
-- - 3 | Atul | Pune
-- - 4 | Rahul | Hyderabad
--
-- Orders Table
--
-- - order_id | customer_id | order_date | amount | aspect
-- - 101 | 1 | 2024-05-01 | 2500 | Electronics
-- - 102 | 1 | 2024-05-03 | 1500 | Books
-- - 103 | 2 | 2024-05-05 | 3000 | Clothing
-- - 104 | 4 | 2024-05-07 | 1200 | Books
-- - 105 | 4 | 2024-05-10 | 2200 | Electronics

-- %%
-- Customer Temp View
CREATE OR REPLACE TEMP VIEW customer AS
SELECT * FROM VALUES
(1, 'Krishna', 'Hyderabad'),
(2, 'Sudheer', 'Bangalore'),
(3, 'Atul', 'Pune'),
(4, 'Rahul', 'Hyderabad')
AS customer(customer_id, customer_name, city);


-- Orders Temp View
CREATE OR REPLACE TEMP VIEW orders AS
SELECT * FROM VALUES
(101, 1, DATE '2024-05-01', 2500, 'Electronics'),
(102, 1, DATE '2024-05-03', 1500, 'Books'),
(103, 2, DATE '2024-05-05', 3000, 'Clothing'),
(104, 4, DATE '2024-05-07', 1200, 'Books'),
(105, 4, DATE '2024-05-10', 2200, 'Electronics')
AS orders(order_id, customer_id, order_date, amount, aspect);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- 1. Question
-- List all customers who have placed at least one order.
-- - Explanation:
-- _We need only those customers who have matching orders._

-- %% [markdown]
-- Expected result
--
-- - 1 | Krishna | Hyderabad
-- - 2 | Sudheer | Bangalore
-- - 4 | Rahul | Hyderabad

-- %%
SELECT c.customer_id, c.customer_name, c.city
FROM Customer c
INNER JOIN Orders o
ON c.customer_id = o.customer_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>city</th></tr></thead><tbody><tr><td>1</td><td>Krishna</td><td>Hyderabad</td></tr><tr><td>1</td><td>Krishna</td><td>Hyderabad</td></tr><tr><td>2</td><td>Sudheer</td><td>Bangalore</td></tr><tr><td>4</td><td>Rahul</td><td>Hyderabad</td></tr><tr><td>4</td><td>Rahul</td><td>Hyderabad</td></tr></tbody></table></div>

-- %% [markdown]
-- ## 2. Question
-- List all customers who have never placed any order.
-- > Explanation:
-- _We need all customers, including those without any orders._

-- %%
SELECT c.customer_id, c.customer_name, c.city
FROM Customer c
LEFT JOIN Orders o
ON c.customer_id = o.customer_id
WHERE o.order_id IS NULL;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>city</th></tr></thead><tbody><tr><td>3</td><td>Atul</td><td>Pune</td></tr></tbody></table></div>

-- %% [markdown]
-- ## 3. Question
-- List customers and their order count (including customers with no orders).
-- > Explanation:
--
-- We need all customers and count how many orders each has.

-- %% [markdown]
-- Expected Result
-- - 1 | Krishna | Hyderabad | 2
-- - 2 | Sudheer | Bangalore | 2
-- - 3 | Atul | Pune | 0
-- - 4 | Rahul | Hyderabad | 2

-- %%
SELECT c.customer_id, c.customer_name, c.city,
       COUNT(o.order_id) AS order_count
FROM Customer c
LEFT JOIN Orders o
ON c.customer_id = o.customer_id
GROUP BY c.customer_id, c.customer_name, c.city
ORDER BY c.customer_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>city</th><th>order_count</th></tr></thead><tbody><tr><td>1</td><td>Krishna</td><td>Hyderabad</td><td>2</td></tr><tr><td>2</td><td>Sudheer</td><td>Bangalore</td><td>1</td></tr><tr><td>3</td><td>Atul</td><td>Pune</td><td>0</td></tr><tr><td>4</td><td>Rahul</td><td>Hyderabad</td><td>2</td></tr></tbody></table></div>

-- %% [markdown]
-- ## 4. Question
-- Find total amount spent by each customer.
-- > Explanation:
-- We need total order amount for each customer.

-- %% [markdown]
-- Expected Result
-- - 1 | Krishna | 4000
-- - 2 | Sudheer | 4500
-- - 3 | Atul | 0
-- - 4 | Rahul | 3400

-- %%
SELECT c.customer_id, c.customer_name,
       COALESCE(SUM(o.amount), 0) AS total_amount
FROM Customer c
LEFT JOIN Orders o
ON c.customer_id = o.customer_id
GROUP BY c.customer_id, c.customer_name
ORDER BY c.customer_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>total_amount</th></tr></thead><tbody><tr><td>1</td><td>Krishna</td><td>4000</td></tr><tr><td>2</td><td>Sudheer</td><td>3000</td></tr><tr><td>3</td><td>Atul</td><td>0</td></tr><tr><td>4</td><td>Rahul</td><td>3400</td></tr></tbody></table></div>

-- %% [markdown]
-- # Employee & Department

-- %%
-- Employee Temp View
CREATE OR REPLACE TEMP VIEW employee AS
SELECT * FROM VALUES
(1, 'Krishna', 1),
(2, 'Parvati', 2),
(3, 'Ashna', 3),
(4, 'Pinki', 1),
(5, 'Shruti', 4)
AS employee(employee_id, name, department_id);


-- Department Temp View
CREATE OR REPLACE TEMP VIEW department AS
SELECT * FROM VALUES
(1, 'HR'),
(2, 'Finance'),
(3, 'IT'),
(4, 'Sales')
AS department(department_id, department_name);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
--  Expected Output
-- - Krishna | HR
-- - Pinki | HR

-- %% [markdown]
-- ## 5. Question
-- List all employees who belong to the 'HR' department.
-- > Explanation:
-- We need employees who are in the HR department.

-- %%
SELECT e.name, d.department_name
FROM Employee e
INNER JOIN Department d
ON e.department_id = d.department_id
WHERE d.department_name = 'HR';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>department_name</th></tr></thead><tbody><tr><td>Krishna</td><td>HR</td></tr><tr><td>Pinki</td><td>HR</td></tr></tbody></table></div>

-- %% [markdown]
-- ## 6. Question
-- List the number of employees in each department.
-- - Explanation:
-- We need to count employees grouped by each department.

-- %% [markdown]
-- Expected Output
-- - Finance | 1
-- - HR | 2
-- - IT | 1
-- - Sales | 1

-- %%
SELECT d.department_name,
       COUNT(e.employee_id) AS employee_count
FROM Department d
LEFT JOIN Employee e
ON d.department_id = e.department_id
GROUP BY d.department_name
ORDER BY d.department_name;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department_name</th><th>employee_count</th></tr></thead><tbody><tr><td>Finance</td><td>1</td></tr><tr><td>HR</td><td>2</td></tr><tr><td>IT</td><td>1</td></tr><tr><td>Sales</td><td>1</td></tr></tbody></table></div>

-- %% [markdown]
-- ## 7. Question
-- List all employees along with their department names.
-- - Explanation:
-- We need to display each employee and the department they belong to.

-- %% [markdown]
-- Expected Output
-- - Ashna | IT
-- - Krishna | HR
-- - Parvati | Finance
-- - Pinki | HR
-- - Shruti | Sales

-- %%
SELECT e.name, d.department_name
FROM Employee e
INNER JOIN Department d
ON e.department_id = d.department_id
ORDER BY e.name;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>department_name</th></tr></thead><tbody><tr><td>Ashna</td><td>IT</td></tr><tr><td>Krishna</td><td>HR</td></tr><tr><td>Parvati</td><td>Finance</td></tr><tr><td>Pinki</td><td>HR</td></tr><tr><td>Shruti</td><td>Sales</td></tr></tbody></table></div>

-- %% [markdown]
-- ## 8. Question
-- List the names of employees who are in departments other than 'HR'.
-- - Explanation:
-- We need employees whose department name is not 'HR'.

-- %% [markdown]
-- Expected Output
-- - Ashna | IT
-- - Parvati | Finance
-- - Shruti | Sales

-- %%
SELECT e.name, d.department_name
FROM Employee e
INNER JOIN Department d
ON e.department_id = d.department_id
WHERE d.department_name <> 'HR'
ORDER BY e.name;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>department_name</th></tr></thead><tbody><tr><td>Ashna</td><td>IT</td></tr><tr><td>Parvati</td><td>Finance</td></tr><tr><td>Shruti</td><td>Sales</td></tr></tbody></table></div>

-- %% [markdown]
-- # E-commerce

-- %%
-- Customer Temp View
CREATE OR REPLACE TEMP VIEW customer_orders_customers AS
SELECT * FROM VALUES
(1, 'Prince', 'prince@gmail.com'),
(2, 'Mohit', 'mohit@gmail.com'),
(3, 'Rahul', 'rahul@gmail.com'),
(4, 'Krishna', 'krishna@gmail.com')
AS customer(customer_id, name, email);


-- Orders Temp View
CREATE OR REPLACE TEMP VIEW customer_orders_orders AS
SELECT * FROM VALUES
(101, 1, DATE '2024-05-01', 1500),
(102, 2, DATE '2024-05-02', 2300),
(103, 3, DATE '2024-05-03', 1800),
(104, 4, DATE '2024-05-04', 2700),
(105, 1, DATE '2024-05-05', 1100)
AS orders(order_id, customer_id, order_date, total_amount);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- ## 9. Question
-- List all customers who have placed an order.

-- %% [markdown]
-- Expected Output
-- - Prince | prince@gmail.com
-- - Mohit | mohit@gmail.com
-- - Rahul | rahul@gmail.com
-- - Krishna | krishna@gmail.com

-- %%
SELECT c.name, c.email
FROM Customer c
WHERE c.customer_id IN
(SELECT customer_id FROM Orders);
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- ## 10. Question
-- List total number of orders placed by each customer.

-- %% [markdown]
-- Expected Output
-- - Prince | 2
-- - Mohit | 1
-- - Rahul | 1
-- - Krishna | 1
-- -

-- %%
SELECT c.name, COUNT(o.order_id) AS total_orders
FROM Customer c
LEFT JOIN Orders o
ON c.customer_id = o.customer_id
GROUP BY c.name
ORDER BY total_orders DESC;
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- ## 11. Question
-- Display the total amount spent by each customer.

-- %% [markdown]
-- - Expected Output
-- - Krishna | 2700
-- - Mohit | 2300
-- - Rahul | 1800
-- Prince | 2600

-- %%
SELECT c.name, COALESCE(SUM(o.total_amount), 0) AS total_spent
FROM Customer c
LEFT JOIN Orders o ON c.customer_id = o.customer_id
GROUP BY c.name
ORDER BY total_spent DESC;
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- ## 12. Question
-- List customers who have not placed any order.

-- %%
SELECT c.name, c.email
FROM Customer c
WHERE c.customer_id NOT IN
(SELECT customer_id FROM Orders);
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- # Banking

-- %%
-- Customers Temp View
CREATE OR REPLACE TEMP VIEW banking_customers AS
SELECT * FROM VALUES
(101, 'Krishna', 'krishna@gmail.com'),
(102, 'Sudheer', 'sudheer@gmail.com'),
(103, 'Raj', 'raj@gmail.com'),
(104, 'Ashna', 'ashna@gmail.com'),
(105, 'Parvati', 'parvati@gmail.com')
AS customers(customer_id, name, email);


-- Accounts Temp View
CREATE OR REPLACE TEMP VIEW banking_accounts AS
SELECT * FROM VALUES
(201, 101, 'Savings', 25000.00),
(202, 102, 'Current', 15000.00),
(203, 103, 'Savings', 32000.00),
(204, 104, 'Current', 18000.00),
(205, 105, 'Savings', 27500.00)
AS accounts(account_id, customer_id, account_type, balance);


-- Transactions Temp View
CREATE OR REPLACE TEMP VIEW banking_transactions AS
SELECT * FROM VALUES
(301, 201, DATE '2024-05-01', 'Deposit', 5000.00),
(302, 202, DATE '2024-05-02', 'Withdrawal', 3000.00),
(303, 201, DATE '2024-05-03', 'Withdrawal', 2000.00),
(304, 203, DATE '2024-05-04', 'Deposit', 4000.00),
(305, 204, DATE '2024-05-05', 'Deposit', 6000.00),
(306, 205, DATE '2024-05-06', 'Withdrawal', 1500.00)
AS transactions(txn_id, account_id, txn_date, txn_type, amount);
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- ## 13. Question
-- List each customer with their account type and current balance.

-- %% [markdown]
-- Expected Output
-- - Ashna | Current | 18000.00
-- - Krishna | Savings | 25000.00
-- - Parvati | Savings | 27500.00
-- - Raj | Savings | 32000.00
-- Sudheer | Current | 15000.00

-- %%
SELECT c.name, a.account_type, a.balance
FROM Customer c
JOIN Accounts a ON c.customer_id = a.customer_id
ORDER BY c.name;
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- ## 14. Question
-- Find the total amount deposited by each customer.

-- %% [markdown]
-- Expected Output
-- - Raj | 4000.00
-- - Ashna | 6000.00
-- - Krishna | 5000.00
-- - Sudheer | 0.00
-- - Parvati | 0.00

-- %%
SELECT c.name, COALESCE(SUM(t.amount), 0) AS total_deposited
FROM Customer c
JOIN Accounts a ON c.customer_id = a.customer_id
LEFT JOIN Transactions t
ON a.account_id = t.account_id AND t.txn_type = 'Deposit'
GROUP BY c.name
ORDER BY total_deposited DESC;
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- # HR Analytics

-- %%
-- Employees Temp View
CREATE OR REPLACE TEMP VIEW hr_employees AS
SELECT * FROM VALUES
(1, 'Ashna', 'HR', 60000, DATE '2022-01-15'),
(2, 'Pinki', 'IT', 70000, DATE '2021-06-20'),
(3, 'Shruti', 'Finance', 65000, DATE '2020-09-10'),
(4, 'Parvati', 'Marketing', 62000, DATE '2023-03-05')
AS employees(emp_id, name, department, salary, hire_date);


-- Performance Temp View
CREATE OR REPLACE TEMP VIEW hr_performance AS
SELECT * FROM VALUES
(101, 1, 4, DATE '2023-06-30'),
(102, 2, 5, DATE '2023-06-30'),
(103, 3, 3, DATE '2023-06-30'),
(104, 4, 4, DATE '2023-06-30'),
(105, 1, 5, DATE '2024-06-30'),
(106, 2, 4, DATE '2024-06-30'),
(107, 3, 4, DATE '2024-06-30'),
(108, 4, 5, DATE '2024-06-30')
AS performance(perf_id, emp_id, rating, review_date);
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- ## 15. Question
-- Find the average salary of employees in each department.

-- %% [markdown]
-- Expected Output
-- - IT | 70000.00
-- - Finance | 65000.00
-- - Marketing | 62000.00
-- - HR | 60000.00

-- %%
SELECT department,
       ROUND(AVG(salary), 2) AS avg_salary
FROM Employees
GROUP BY department
ORDER BY avg_salary DESC;
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- ## 16. Question
-- List the employees who received a rating of 4 or above in their latest performance review.

-- %% [markdown]
-- Expected Output
-- - Ashna | 5 | 2024-06-30
-- - Parvati | 5 | 2024-06-30
-- - Pinki | 4 | 2024-06-30
-- - Shruti | 4 | 2024-06-30

-- %%
SELECT e.name, p.rating, p.review_date
FROM Employees e
JOIN Performance p ON e.emp_id = p.emp_id
WHERE (e.emp_id, p.review_date) IN (
    SELECT emp_id, MAX(review_date)
    FROM Performance
    GROUP BY emp_id
)
AND p.rating >= 4
ORDER BY e.name;
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- # Healthcare

-- %%
-- Patients Temp View
CREATE OR REPLACE TEMP VIEW hospital_patients AS
SELECT * FROM VALUES
(1, 'Raj', 35, 'Male'),
(2, 'Mohit', 42, 'Male'),
(3, 'Prince', 29, 'Male'),
(4, 'Rahul', 31, 'Male')
AS patients(patient_id, name, age, gender);


-- Doctors Temp View
CREATE OR REPLACE TEMP VIEW hospital_doctors AS
SELECT * FROM VALUES
(101, 'Dr. Mehta', 'Cardiology'),
(102, 'Dr. Sharma', 'Neurology'),
(103, 'Dr. Verma', 'Orthopedics')
AS doctors(doctor_id, name, specialization);


-- Appointments Temp View
CREATE OR REPLACE TEMP VIEW hospital_appointments AS
SELECT * FROM VALUES
(1001, 1, 101, DATE '2024-05-01', 'Chest Pain', 800),
(1002, 2, 102, DATE '2024-05-02', 'Headache', 700),
(1003, 3, 103, DATE '2024-05-03', 'Knee Pain', 600),
(1004, 1, 103, DATE '2024-05-05', 'Back Pain', 600),
(1005, 4, 101, DATE '2024-05-06', 'Regular Checkup', 800),
(1006, 2, 101, DATE '2024-05-07', 'Follow Up', 800)
AS appointments(appt_id, patient_id, doctor_id, appt_date, reason, fees);
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- ## 17. Question
-- Find the number of appointments booked by each patient.

-- %% [markdown]
-- Expected Output
-- - Raj | 2
-- - Mohit | 2
-- - Prince | 1
-- - Rahul | 1

-- %%
SELECT p.name, COUNT(a.appt_id) AS total_appointments
FROM Patients p
LEFT JOIN Appointments a
ON p.patient_id = a.patient_id
GROUP BY p.name
ORDER BY total_appointments DESC;
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- ## 18. Question
-- Find the total fees collected by each doctor.

-- %% [markdown]
-- Expected Output
-- - Dr. Mehta | 2400
-- - Dr. Verma | 1200
-- - Dr. Sharma | 700

-- %%
SELECT d.name, SUM(a.fees) AS total_fees
FROM Doctors d
JOIN Appointments a
ON d.doctor_id = a.doctor_id
GROUP BY d.name
ORDER BY total_fees DESC;
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- # Retail

-- %%
-- Customers Temp View
CREATE OR REPLACE TEMP VIEW ecommerce_customers AS
SELECT * FROM VALUES
(1, 'Rahul', 'rahul@gmail.com', 'Delhi'),
(2, 'Prince', 'prince@gmail.com', 'Mumbai'),
(3, 'Mohit', 'mohit@gmail.com', 'Bangalore'),
(4, 'Sudheer', 'sudheer@gmail.com', 'Hyderabad')
AS customers(customer_id, name, email, city);


-- Products Temp View
CREATE OR REPLACE TEMP VIEW ecommerce_products AS
SELECT * FROM VALUES
(101, 'T-Shirt', 'Apparel', 599.00),
(102, 'Jeans', 'Apparel', 1299.00),
(103, 'Sneakers', 'Footwear', 2499.00),
(104, 'Backpack', 'Accessories', 899.00),
(105, 'Watch', 'Accessories', 1499.00)
AS products(product_id, product_name, category, price);


-- Orders Temp View
CREATE OR REPLACE TEMP VIEW ecommerce_orders AS
SELECT * FROM VALUES
(201, 1, DATE '2024-05-01', 1898.00, 'UPI'),
(202, 2, DATE '2024-05-02', 2499.00, 'Credit Card'),
(203, 3, DATE '2024-05-03', 1399.00, 'Debit Card'),
(204, 1, DATE '2024-05-04', 599.00, 'UPI'),
(205, 4, DATE '2024-05-05', 3898.00, 'Credit Card'),
(206, 2, DATE '2024-05-06', 899.00, 'UPI')
AS orders(order_id, customer_id, order_date, total_amount, payment_mode);
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- ## 19. Question
-- List each customer and the total amount of all orders placed by them

-- %% [markdown]
-- Expected Output
-- - Sudheer | 3898.00
-- - Prince | 3398.00
-- - Rahul | 2497.00
-- - Mohit | 1399.00

-- %%
SELECT c.name, SUM(o.total_amount) AS total_spent
FROM Customers c
LEFT JOIN Orders o
ON c.customer_id = o.customer_id
GROUP BY c.name
ORDER BY total_spent DESC;
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- ## 20. Question
-- Find the most expensive product in each category

-- %% [markdown]
-- Expected Output
-- - Apparel | Jeans | 1299.00
-- - Footwear | Sneakers | 2499.00
-- - Accessories | Watch | 1499.00

-- %%
SELECT category, product_name, price
FROM Products p1
WHERE price = (
    SELECT MAX(price)
    FROM Products p2
    WHERE p1.category = p2.category
);
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- # Logistics

-- %%
-- Drivers Temp View
CREATE OR REPLACE TEMP VIEW logistics_drivers AS
SELECT * FROM VALUES
(1, 'Raj', '9876543210', 'DL01AB1234'),
(2, 'Atul', '9123456780', 'MH12CD5678'),
(3, 'Sudheer', '9988776655', 'KA03EF9012'),
(4, 'Krishna', '8899001122', 'TS07GH3456')
AS drivers(driver_id, name, phone, vehicle_no);


-- Shipments Temp View
CREATE OR REPLACE TEMP VIEW logistics_shipments AS
SELECT * FROM VALUES
(101, 'Delhi', 'Mumbai', 1200, 'Delivered'),
(102, 'Hyderabad', 'Bangalore', 800, 'In Transit'),
(103, 'Chennai', 'Kolkata', 1500, 'Delivered'),
(104, 'Pune', 'Delhi', 600, 'In Transit'),
(105, 'Jaipur', 'Ahmedabad', 1100, 'Pending')
AS shipments(shipment_id, origin, destination, weight_kg, status);


-- Deliveries Temp View
CREATE OR REPLACE TEMP VIEW logistics_deliveries AS
SELECT * FROM VALUES
(501, 101, 1, DATE '2024-05-01', 1480, 8500.00),
(502, 102, 2, DATE '2024-05-02', 580, 4200.00),
(503, 103, 3, DATE '2024-05-03', 1670, 9300.00),
(504, 104, 4, DATE '2024-05-04', 1210, 6900.00),
(505, 105, 2, DATE '2024-05-05', 910, 5100.00)
AS deliveries(delivery_id, shipment_id, driver_id, delivery_date, distance_km, freight_amount);
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- ## 21. Question
-- Find the total freight amount earned by each driver.

-- %% [markdown]
-- Expected Output
-- - Sudheer | 9300.00
-- - Atul | 9300.00
-- - Raj | 8500.00
-- - Krishna | 6900.00

-- %%
SELECT d.name, SUM(del.freight_amount) AS total_freight
FROM Drivers d
JOIN Deliveries del
ON d.driver_id = del.driver_id
GROUP BY d.name
ORDER BY total_freight DESC;
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- ## 22. Question
-- Find the number of shipments in each status.

-- %% [markdown]
-- Expected Output
-- - Delivered | 2
-- - In Transit | 2
-- - Pending | 1

-- %%
SELECT status, COUNT(shipment_id) AS total_shipments
FROM Shipments
GROUP BY status
ORDER BY total_shipments DESC;
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- # Advanced Join Scenarios

-- %%
-- Customers Temp View
CREATE OR REPLACE TEMP VIEW retail_customers AS
SELECT * FROM VALUES
(1, 'Atul', 'Delhi'),
(2, 'Prince', 'Mumbai'),
(3, 'Mohit', 'Bangalore'),
(4, 'Rahul', 'Chennai')
AS customers(customer_id, name, city);


-- Orders Temp View
CREATE OR REPLACE TEMP VIEW retail_orders AS
SELECT * FROM VALUES
(101, 1, DATE '2024-05-01'),
(102, 1, DATE '2024-05-05'),
(103, 2, DATE '2024-05-03'),
(104, 3, DATE '2024-05-07'),
(105, 3, DATE '2024-05-10')
AS orders(order_id, customer_id, order_date);


-- Payments Temp View
CREATE OR REPLACE TEMP VIEW retail_payments AS
SELECT * FROM VALUES
(201, 101, 2500.00),
(202, 102, 1250.00),
(203, 103, 3000.00),
(204, 104, 1750.00),
(205, 106, 2200.00)   -- Note: order_id 106 not present in orders table
AS payments(payment_id, order_id, amount);
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- ## 23. Question
-- List all customers along with the orders they have placed. Include customers who have not placed any orders

-- %% [markdown]
-- Expected Output
-- - 1 | Atul | 101 | 2024-05-01
-- - 1 | Atul | 102 | 2024-05-05
-- - 2 | Prince | 103 | 2024-05-03
-- - 3 | Mohit | 104 | 2024-05-07
-- - 4 | Rahul | NULL | NULL

-- %%
SELECT c.customer_id, c.name, o.order_id, o.order_date
FROM Customers c
LEFT JOIN Orders o
ON c.customer_id = o.customer_id
ORDER BY c.customer_id, o.order_date;
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- ## 24. Question
-- List all payments along with the customer who placed the order. Include payments for orders where customer details are not available.

-- %% [markdown]
-- Expected Output
-- - 201 | 2500.00 | 101 | Atul
-- - 202 | 1250.00 | 102 | Atul
-- - 203 | 3000.00 | 103 | Prince
-- - 204 | 1750.00 | 104 | Mohit
-- - 205 | 2200.00 | 106 | NULL

-- %%
SELECT p.payment_id, p.amount, o.order_id,
       c.name AS customer_name
FROM Payments p
LEFT JOIN Orders o ON p.order_id = o.order_id
LEFT JOIN Customers c ON o.customer_id = c.customer_id
ORDER BY p.payment_id;
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- ## 25. Question
-- List all customers who have not placed any orders

-- %% [markdown]
-- Expected Output
-- 4 | Rahul | Chennai

-- %%
SELECT c.customer_id, c.name, c.city
FROM Customers c
LEFT JOIN Orders o
ON c.customer_id = o.customer_id
WHERE o.order_id IS NULL;
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- # Bonus SQL Questions

-- %%
-- Customers Temp View
CREATE OR REPLACE TEMP VIEW retail2_customers AS
SELECT * FROM VALUES
(1, 'Asha', 'Delhi'),
(2, 'Parvati', 'Mumbai'),
(3, 'Pinki', 'Bangalore'),
(4, 'Krishna', 'Chennai')
AS customers(customer_id, name, city);


-- Orders Temp View
CREATE OR REPLACE TEMP VIEW retail2_orders AS
SELECT * FROM VALUES
(101, 1, DATE '2024-05-01'),
(102, 1, DATE '2024-05-05'),
(103, 2, DATE '2024-05-03'),
(104, 3, DATE '2024-05-07'),
(105, 4, DATE '2024-05-10')
AS orders(order_id, customer_id, order_date);


-- Payments Temp View
CREATE OR REPLACE TEMP VIEW retail2_payments AS
SELECT * FROM VALUES
(201, 101, 2800.00),
(202, 102, 1500.00),
(203, 103, 3200.00),
(204, 104, 2100.00),
(205, 106, 1900.00)  -- Invalid order_id (does not exist in orders)
AS payments(payment_id, order_id, amount);
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- Find the total amount of payments made by each customer. Include customers who have not made any payment.

-- %% [markdown]
-- Expected Output
-- - 1 | Asha | 4300.00
-- - 2 | Parvati | 3200.00
-- - 3 | Pinki | 2100.00
-- - 4 | Krishna | 0.00

-- %%
SELECT c.customer_id, c.name,
       COALESCE(SUM(p.amount), 0) AS total_payment
FROM Customers c
LEFT JOIN Orders o
ON c.customer_id = o.customer_id
LEFT JOIN Payments p
ON o.order_id = p.order_id
GROUP BY c.customer_id, c.name
ORDER BY c.customer_id;
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...

-- %% [markdown]
-- Show each order along with customer name and payment amount (if any). Include orders that do not have any payment.

-- %% [markdown]
-- Expected Output
-- - 101 | 2024-05-01 | Asha | 2800.00
-- - 102 | 2024-05-05 | Asha | 1500.00
-- - 103 | 2024-05-03 | Parvati | 3200.00
-- - 104 | 2024-05-07 | Pinki | 2100.00
-- - 105 | 2024-05-10 | Krishna | NULL

-- %%
SELECT o.order_id, o.order_date, c.name,
       p.amount AS payment_amount
FROM Orders o
LEFT JOIN Customers c
ON o.customer_id = c.customer_id
LEFT JOIN Payments p
ON o.order_id = p.order_id
ORDER BY o.order_id;
-- Out:
-- org.apache.spark.sql.catalyst.ExtendedAnalysisException: [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `c`.`name` cannot be resolved. Did you mean one of the following? [`c`.`city`, `c`.`customer_id`, `c`.`customer_name`]. SQLSTATE: 42703; line 1 pos 7;
-- 'Project ['c.name, 'c.email]
-- +- Filter customer_id#7146445 IN (list#7146444 [])
--    :  +- Project [customer_id#7146452]
--    :     +- SubqueryAlias orders
--    :        +- View (`orders`, [order_id#7146451, customer_id#7146452, order_date#7146453, amount#7146454, aspect#7146455])
--    :           +- Project [cast(order_id#7146456 as int) AS order_id#7146451, cast(customer_id#7146457 as int) AS customer_id#7146452, cast(order_date#7146458 as date) AS order_date#7146453, cast(amount#7146459 as int) AS amount#7146454, cast(aspect#7146460 as string) AS aspect#7146455]
-- ...
